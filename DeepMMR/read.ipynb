# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, TensorDataset
from src.utils.setseed import set_seed

set_seed(20048)

# %%
a1 = torch.tensor([1, 1, -1, 1])  # batch 4 行
a2 = torch.tensor([-1,1,1,-1])  # batch 4 行，2 列
# Out:
# tensor(True)

# %%
x = {0,1}
for y in x:
    print(y)
